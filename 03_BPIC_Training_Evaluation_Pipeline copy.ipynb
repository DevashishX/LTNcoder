# %% [markdown]
# # Training and Evaluation in one Notebook for One Model-Database Pair

# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices('GPU')
print(physical_devices)
if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print("GPU found")
    print("Memory growth set")
else:
    print("No GPU found")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU found
# Memory growth set

# %%
import arrow
import socket
from sqlalchemy.orm import Session
from tqdm.notebook import tqdm

from april.anomalydetection import *
from april.database import EventLog
from april.database import Model
from april.database import get_engine
from april.dataset import Dataset
from april.fs import DATE_FORMAT
from april.fs import get_event_log_files

import itertools

from sklearn import metrics


from april.anomalydetection import BINet
from april.anomalydetection.utils import label_collapse
from april.database import Evaluation
from april.evaluator import Evaluator
from april.fs import get_model_files
from april.fs import PLOT_DIR

import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)

import pandas as pd
import seaborn as sns
from sqlalchemy.orm import Session
import scikit_posthocs as sp

from april.database import get_engine
from april.fs import PLOT_DIR
from april.utils import microsoft_colors, prettify_dataframe, cd_plot, get_cd
from april.enums import Base, Strategy, Heuristic

sns.set_style('white')
pd.set_option('display.max_rows', 50)
# %config InlineBackend.figure_format = 'retina'
print(p2p_leaky_row_classes)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU found
# Memory growth set
# Creating Evaluation table
# [<class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-10'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-25'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-50'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-100'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-150'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-200'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-250'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-300'>, <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-350'>]

# %%
dataset = "p2p-0.3-1"
out_dir = PLOT_DIR / f'p2p_evaluations_leaky_{arrow.now().format("YYYY-MM-DD-HH-mm-ss")}'
eval_file = out_dir / 'p2p_fraction_evaluations.pkl'
csv_file = out_dir / 'p2p_fraction_evaluations.csv'
excel_file = out_dir / 'p2p_fraction_evaluations.xlsx'
model_folder = r"D:\LTNcoder\.out\models"
db = r"D:\LTNcoder\.out\april.db"

# code to create out_dir if it does not exist
if not out_dir.exists():
    out_dir.mkdir(parents=True, exist_ok=True)
    print(f"Created directory: {out_dir}")
from april.utils import delete_all_files_in_folder, delete_evaluation_and_model_tables
delete_all_files_in_folder(model_folder)
delete_evaluation_and_model_tables(db)
# Out:
# Created directory: d:\LTNcoder\.out\plots\p2p_evaluations_leaky_2025-06-26-12-43-51
# Deleted all rows from Evaluation and Model tables.

# %% [markdown]
# # Training

# %%
def fit_and_save(dataset_name, ad, ad_kwargs=None, fit_kwargs=None):
    if ad_kwargs is None:
        ad_kwargs = {}
    if fit_kwargs is None:
        fit_kwargs = {}

    # Save start time
    start_time = arrow.now()

    # Dataset
    dataset = Dataset(dataset_name)

    # AD
    ad = ad(**ad_kwargs)

    # Train and save
    ad.fit(dataset, **fit_kwargs)
    file_name = f'{dataset_name}_{ad.abbreviation}_{start_time.format(DATE_FORMAT)}'
    model_file = ad.save(file_name)

    # Save end time
    end_time = arrow.now()

    # Cache result
    Evaluator(model_file.str_path).cache_result()

    # Calculate training time in seconds
    training_time = (end_time - start_time).total_seconds()

    # Write to database
    engine = get_engine()
    session = Session(engine)

    session.add(Model(creation_date=end_time.datetime,
                      algorithm=ad.name,
                      training_duration=training_time,
                      file_name=model_file.file,
                      training_event_log_id=EventLog.get_id_by_name(dataset_name),
                      training_host=socket.gethostname(),
                      hyperparameters=str(dict(**ad_kwargs, **fit_kwargs))))
    session.commit()
    session.close()

    if isinstance(ad, NNAnomalyDetector):
        from keras.backend import clear_session
        clear_session()
    pass

# %%
# ads = [
#     dict(ad=Bpic12DAE, fit_kwargs=dict(epochs=1, batch_size=100)),
#     dict(ad=Bpic12LTN, fit_kwargs=dict(epochs=1, batch_size=100, epochs_ltn=1)),
#     dict(ad=Bpic12LTNFROZEN, fit_kwargs=dict(epochs=1, batch_size=100, epochs_ltn=1)),    
# ]
ads = [
    dict(ad=P2pDAE, fit_kwargs=dict(epochs=6, batch_size=100)),
    # dict(ad=Bpic12LTN, fit_kwargs=dict(epochs=8, batch_size=100, epochs_ltn=3)),
    # dict(ad=Bpic12LTNFROZEN, fit_kwargs=dict(epochs=8, batch_size=100, epochs_ltn=3))
    ]  + \
        [dict(ad=LEAKY_ROW_CLASS, fit_kwargs=dict(epochs=6, batch_size=100)) for LEAKY_ROW_CLASS 
   in p2p_leaky_row_classes] 
    # + [dict(ad=LTN_ROW_CLASS, fit_kwargs=dict(epochs=8, batch_size=100, epochs_ltn=3))
    # for LTN_ROW_CLASS in ltn_row_classes]
for ad in tqdm(ads, desc="Fitting ADs"):
    fit_and_save(dataset, **ad)
# Out:
# Fitting ADs:   0%|          | 0/10 [00:00<?, ?it/s]
# Epoch 1/6
# 42/42 [==============================] - 1s 10ms/step - loss: 0.2080 - accuracy: 0.0134 - val_loss: 0.0940 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0204 - accuracy: 0.1146 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 3/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.2000 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 4/6
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.2088 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 5/6
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.2155 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 6/6
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.2297 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae_20250626-124352.019136.keras
# Loading model p2p-0.3-1_p2pdae_20250626-124352.019136 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 1ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 355
# Epoch 1/6
# 42/42 [==============================] - 1s 10ms/step - loss: 0.2045 - accuracy: 9.5694e-04 - val_loss: 0.0871 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0191 - accuracy: 0.0304 - val_loss: 0.0048 - val_accuracy: 0.0000e+00
# Epoch 3/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.0902 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 4/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.0938 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 5/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.1158 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 6/6
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 0.1134 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-10_20250626-124355.984062.keras
# Loading model p2p-0.3-1_p2pdae-leaky-10_20250626-124355.984062 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 340
# Epoch 1/6
# 42/42 [==============================] - 1s 11ms/step - loss: 0.2085 - accuracy: 0.0370 - val_loss: 0.0988 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0216 - accuracy: 0.3774 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 3/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.6218 - val_loss: 0.0047 - val_accuracy: 1.0000
# Epoch 4/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.6173 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 5/6
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.6004 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 6/6
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 0.5603 - val_loss: 0.0044 - val_accuracy: 1.0000
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-25_20250626-124359.015366.keras
# Loading model p2p-0.3-1_p2pdae-leaky-25_20250626-124359.015366 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 315
# Epoch 1/6
# 43/43 [==============================] - 1s 10ms/step - loss: 0.2088 - accuracy: 0.0920 - val_loss: 0.0914 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0195 - accuracy: 0.3980 - val_loss: 0.0047 - val_accuracy: 0.8614
# Epoch 3/6
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0052 - accuracy: 0.5078 - val_loss: 0.0046 - val_accuracy: 0.9275
# Epoch 4/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.5145 - val_loss: 0.0046 - val_accuracy: 0.9296
# Epoch 5/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.5221 - val_loss: 0.0045 - val_accuracy: 0.9510
# Epoch 6/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.5353 - val_loss: 0.0043 - val_accuracy: 0.9275
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-50_20250626-124402.322255.keras
# Loading model p2p-0.3-1_p2pdae-leaky-50_20250626-124402.322255 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 1ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 265
# Epoch 1/6
# 43/43 [==============================] - 1s 9ms/step - loss: 0.2048 - accuracy: 0.0652 - val_loss: 0.0827 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 0.2882 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 3/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.3673 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 4/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.3642 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 5/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.3701 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 6/6
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.3938 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-100_20250626-124405.343325.keras
# Loading model p2p-0.3-1_p2pdae-leaky-100_20250626-124405.343325 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 215
# Epoch 1/6
# 44/44 [==============================] - 1s 9ms/step - loss: 0.2031 - accuracy: 0.0137 - val_loss: 0.0753 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0165 - accuracy: 0.1828 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 3/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.2894 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 4/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.2993 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 5/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.3156 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 6/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.3340 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-150_20250626-124408.342942.keras
# Loading model p2p-0.3-1_p2pdae-leaky-150_20250626-124408.342942 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 165
# Epoch 1/6
# 44/44 [==============================] - 1s 10ms/step - loss: 0.2066 - accuracy: 0.0083 - val_loss: 0.0846 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 0.2661 - val_loss: 0.0047 - val_accuracy: 0.9917
# Epoch 3/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.5390 - val_loss: 0.0046 - val_accuracy: 0.9607
# Epoch 4/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.5238 - val_loss: 0.0045 - val_accuracy: 0.9360
# Epoch 5/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.5293 - val_loss: 0.0044 - val_accuracy: 0.8616
# Epoch 6/6
# 44/44 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 0.5125 - val_loss: 0.0042 - val_accuracy: 0.7913
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-200_20250626-124411.324740.keras
# Loading model p2p-0.3-1_p2pdae-leaky-200_20250626-124411.324740 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 115
# Epoch 1/6
# 44/44 [==============================] - 1s 11ms/step - loss: 0.2029 - accuracy: 0.0171 - val_loss: 0.0777 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0163 - accuracy: 0.2814 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 3/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.4563 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 4/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.4652 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 5/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.4672 - val_loss: 0.0044 - val_accuracy: 0.0552
# Epoch 6/6
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.4864 - val_loss: 0.0043 - val_accuracy: 0.3354
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-250_20250626-124414.527391.keras
# Loading model p2p-0.3-1_p2pdae-leaky-250_20250626-124414.527391 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 1ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 65
# Epoch 1/6
# 45/45 [==============================] - 1s 10ms/step - loss: 0.1999 - accuracy: 0.0507 - val_loss: 0.0659 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0145 - accuracy: 0.3592 - val_loss: 0.0047 - val_accuracy: 0.1215
# Epoch 3/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.4623 - val_loss: 0.0046 - val_accuracy: 0.1457
# Epoch 4/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.4715 - val_loss: 0.0045 - val_accuracy: 0.1478
# Epoch 5/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.4713 - val_loss: 0.0044 - val_accuracy: 0.1640
# Epoch 6/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.4751 - val_loss: 0.0042 - val_accuracy: 0.2935
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-300_20250626-124417.691193.keras
# Loading model p2p-0.3-1_p2pdae-leaky-300_20250626-124417.691193 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39
# Length of LTN rows which will be excluded: 15
# Epoch 1/6
# 45/45 [==============================] - 1s 10ms/step - loss: 0.2006 - accuracy: 0.0203 - val_loss: 0.0690 - val_accuracy: 0.0000e+00
# Epoch 2/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 0.1877 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 3/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.3125 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 4/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.3315 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 5/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.3446 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 6/6
# 45/45 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.3533 - val_loss: 0.0043 - val_accuracy: 0.0000e+00
# d:\LTNcoder\.out\models\p2p-0.3-1_p2pdae-leaky-350_20250626-124421.052418.keras
# Loading model p2p-0.3-1_p2pdae-leaky-350_20250626-124421.052418 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# 12/12 [==============================] - 0s 2ms/step
# Eventlog id for p2p-0.3-1 is 39

# %%
print(AD)
# Out:
# {'binetv0': <class 'april.anomalydetection.binet.binet.BINetv0'>, 'binetv1': <class 'april.anomalydetection.binet.binet.BINetv1'>, 'binetv2': <class 'april.anomalydetection.binet.binet.BINetv2'>, 'binetv3': <class 'april.anomalydetection.binet.binet.BINetv3'>, 'likelihood': <class 'april.anomalydetection.boehmer.BoehmerLikelihoodAnomalyDetector'>, 'bpic12dae': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE'>, 'bpic12dae-leaky-10': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-10'>, 'bpic12dae-leaky-100': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-100'>, 'bpic12dae-leaky-150': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-150'>, 'bpic12dae-leaky-200': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-200'>, 'bpic12dae-leaky-25': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-25'>, 'bpic12dae-leaky-250': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-250'>, 'bpic12dae-leaky-300': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-300'>, 'bpic12dae-leaky-350': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-350'>, 'bpic12dae-leaky-400': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-400'>, 'bpic12dae-leaky-50': <class 'april.anomalydetection.bpic12encoder.Bpic12DAE-Leaky-50'>, 'Bpic12ltn': <class 'april.anomalydetection.bpic12encoder.Bpic12LTN'>, 'bpic12ltnfrozen': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN'>, 'bpic12ltnfrozen-10': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-10'>, 'bpic12ltnfrozen-100': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-100'>, 'bpic12ltnfrozen-150': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-150'>, 'bpic12ltnfrozen-200': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-200'>, 'bpic12ltnfrozen-25': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-25'>, 'bpic12ltnfrozen-250': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-250'>, 'bpic12ltnfrozen-300': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-300'>, 'bpic12ltnfrozen-350': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-350'>, 'bpic12ltnfrozen-400': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-400'>, 'bpic12ltnfrozen-50': <class 'april.anomalydetection.bpic12encoder.Bpic12LTNFROZEN-50'>, 'dae': <class 'april.anomalydetection.autoencoder.DAE'>, 'daeltn': <class 'april.anomalydetection.autoencoder.DAELTN'>, 'daeltnfrozen': <class 'april.anomalydetection.autoencoder.DAELTNFROZEN'>, 'likelihood+': <class 'april.anomalydetection.boehmer.LikelihoodPlusAnomalyDetector'>, 'naive': <class 'april.anomalydetection.bezerra.NaiveAnomalyDetector'>, 'naive+': <class 'april.anomalydetection.bezerra.NaivePlusAnomalyDetector'>, 'one-class-svm': <class 'april.anomalydetection.basic.OneClassSVM'>, 'p2pdae': <class 'april.anomalydetection.p2pencoder.P2pDAE'>, 'p2pdae-leaky-10': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-10'>, 'p2pdae-leaky-100': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-100'>, 'p2pdae-leaky-150': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-150'>, 'p2pdae-leaky-200': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-200'>, 'p2pdae-leaky-25': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-25'>, 'p2pdae-leaky-250': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-250'>, 'p2pdae-leaky-300': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-300'>, 'p2pdae-leaky-350': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-350'>, 'p2pdae-leaky-50': <class 'april.anomalydetection.p2pencoder.P2pDAE-Leaky-50'>, 'p2pltn': <class 'april.anomalydetection.p2pencoder.P2pLTN'>, 'p2pltnfrozen': <class 'april.anomalydetection.p2pencoder.P2pLTNFROZEN'>, 'p2pltnfrozen-10': <class 'april.anomalydetection.p2pencoder.P2pLTNFROZEN-10'>, 'p2pltnfrozen-100': <class 'april.anomalydetection.p2pencoder.P2pLTNFROZEN-100'>, 'p2pltnfrozen-150': <clas ...

# %% [markdown]
# # Evaluation

# %%
heuristics = [h for h in Heuristic.keys() if h not in [Heuristic.DEFAULT, Heuristic.MANUAL, Heuristic.RATIO,
                                                       Heuristic.MEDIAN, Heuristic.MEAN]]
params = [(Base.SCORES, Heuristic.DEFAULT, Strategy.SINGLE), *itertools.product([Base.SCORES], heuristics, Strategy.keys())]

# %%
def _evaluate(params):
    # print(f"Evaluating {params}...")
    e, base, heuristic, strategy = params
    e = Evaluator(e.model_file.name)
    session = Session(get_engine())
    model = session.query(Model).filter_by(file_name=e.model_file.name).first()
    session.close()
    # print(f"Model {model} loaded from Session.")

    if Model is None:
        print(f"Models from session: {model}")
    # Generate evaluation frames
    
    # print the socres in e: Evaluator
    print(f"in _evaluate Evaluating model {model} with base={base}, heuristic={heuristic}, strategy={strategy}")
    print(f"e.")
    y_pred = e.binarizer.binarize(base=base, heuristic=heuristic, strategy=strategy, go_backwards=False)
    y_true = e.binarizer.get_targets()

    evaluations = []
    for axis in [0, 1, 2]:
        # print(f"Evaluating axis {axis}...")
        for i, attribute_name in enumerate(e.dataset.attribute_keys):
            # print(f"Evaluating attribute {attribute_name}...")
            def get_evaluation(label, precision, recall, f1):
                return Evaluation(model_id=model.id, file_name=model.file_name,
                                  label=label, perspective=perspective, attribute_name=attribute_name,
                                  axis=axis, base=base, heuristic=heuristic, strategy=strategy,
                                  precision=precision, recall=recall, f1=f1)

            perspective = 'Control Flow' if i == 0 else 'Data'
            if i > 0 and not e.ad_.supports_attributes:
                # print(f"Skipping attribute {attribute_name} for model {model} as it does not support attributes.")
                evaluations.append(get_evaluation('Normal', 0.0, 0.0, 0.0))
                evaluations.append(get_evaluation('Anomaly', 0.0, 0.0, 0.0))
            else:
                # print(f"Evaluating attribute {attribute_name} for model {model}...")
                yp = label_collapse(y_pred[:, :, i:i + 1], axis=axis).compressed()
                yt = label_collapse(y_true[:, :, i:i + 1], axis=axis).compressed()
                p, r, f, _ = metrics.precision_recall_fscore_support(yt, yp, labels=[0, 1])
                evaluations.append(get_evaluation('Normal', p[0], r[0], f[0]))
                evaluations.append(get_evaluation('Anomaly', p[1], r[1], f[1]))

    return evaluations

def evaluate(model_name):
    # print(f"Evaluating {model_name}...")
    e = Evaluator(model_name)
    # print(f"{e} loaded.")

    _params = []
    for base, heuristic, strategy in params:
        if e.dataset.num_attributes == 1 and strategy in [Strategy.ATTRIBUTE, Strategy.POSITION_ATTRIBUTE]:
            continue
        if isinstance(e.ad_, BINet) and e.ad_.version == 0:
            continue
        if heuristic is not None and heuristic not in e.ad_.supported_heuristics:
            continue
        if strategy is not None and strategy not in e.ad_.supported_strategies:
            continue
        if base is not None and base not in e.ad_.supported_bases:
            continue
        _params.append([e, base, heuristic, strategy])

    return [_e for p in _params for _e in _evaluate(p)]

# %%
models = sorted([m.name for m in get_model_files() if m.p == 0.3])# and 'real' in m.name])
print(f"Available Models: {models}")
evaluations = []
for model in tqdm(models, desc='Evaluate'):
    e = evaluate(model)
    evaluations.append(e)
# Write to database
session = Session(get_engine())
for e in evaluations:
    session.bulk_save_objects(e)
    session.commit()
session.close()
# Out:
# Available Models: ['p2p-0.3-1_p2pdae-leaky-100_20250626-124405.343325', 'p2p-0.3-1_p2pdae-leaky-10_20250626-124355.984062', 'p2p-0.3-1_p2pdae-leaky-150_20250626-124408.342942', 'p2p-0.3-1_p2pdae-leaky-200_20250626-124411.324740', 'p2p-0.3-1_p2pdae-leaky-250_20250626-124414.527391', 'p2p-0.3-1_p2pdae-leaky-25_20250626-124359.015366', 'p2p-0.3-1_p2pdae-leaky-300_20250626-124417.691193', 'p2p-0.3-1_p2pdae-leaky-350_20250626-124421.052418', 'p2p-0.3-1_p2pdae-leaky-50_20250626-124402.322255', 'p2p-0.3-1_p2pdae_20250626-124352.019136']
# Evaluate:   0%|          | 0/10 [00:00<?, ?it/s]
# Loading model p2p-0.3-1_p2pdae-leaky-100_20250626-124405.343325 for event log p2p-0.3-1
# Filtering dataset to 365 LTN rows.
# Indices: [24, 48, 67, 76, 86, 94, 147, 161, 190, 256, 262, 284, 318, 374, 386, 413, 419, 420, 425, 478, 483, 494, 501, 510, 512, 548, 551, 563, 569, 577, 617, 625, 640, 642, 676, 707, 721, 790, 804, 816, 820, 854, 883, 888, 920, 945, 954, 1013, 1015, 1043, 1047, 1056, 1073, 1077, 1082, 1094, 1110, 1115, 1127, 1137, 1150, 1183, 1195, 1237, 1249, 1262, 1266, 1296, 1306, 1328, 1356, 1378, 1391, 1395, 1401, 1412, 1417, 1434, 1458, 1473, 1490, 1494, 1508, 1518, 1559, 1579, 1600, 1607, 1608, 1634, 1651, 1674, 1678, 1703, 1761, 1778, 1779, 1785, 1795, 1811, 1822, 1855, 1874, 1875, 1902, 1903, 1907, 1908, 1937, 1941, 1944, 2009, 2027, 2039, 2040, 2042, 2045, 2049, 2050, 2059, 2108, 2116, 2129, 2157, 2169, 2175, 2183, 2206, 2210, 2222, 2233, 2237, 2258, 2262, 2265, 2281, 2293, 2313, 2321, 2337, 2344, 2352, 2354, 2361, 2364, 2375, 2376, 2379, 2383, 2397, 2398, 2399, 2408, 2410, 2425, 2430, 2444, 2447, 2463, 2464, 2487, 2497, 2538, 2596, 2612, 2621, 2628, 2652, 2679, 2695, 2709, 2719, 2738, 2745, 2748, 2750, 2763, 2766, 2774, 2787, 2795, 2823, 2831, 2846, 2850, 2855, 2859, 2861, 2878, 2913, 2925, 2929, 2951, 2952, 2956, 2969, 2971, 2975, 2976, 2982, 3011, 3028, 3045, 3061, 3068, 3071, 3074, 3077, 3083, 3084, 3086, 3095, 3097, 3105, 3133, 3159, 3172, 3173, 3205, 3208, 3210, 3222, 3239, 3290, 3296, 3304, 3309, 3322, 3327, 3347, 3351, 3368, 3384, 3389, 3392, 3397, 3409, 3410, 3425, 3455, 3457, 3464, 3477, 3494, 3501, 3507, 3512, 3514, 3534, 3554, 3562, 3569, 3577, 3600, 3606, 3613, 3636, 3647, 3657, 3658, 3683, 3688, 3717, 3718, 3732, 3735, 3747, 3754, 3769, 3787, 3789, 3792, 3808, 3809, 3815, 3857, 3866, 3932, 3943, 4000, 4015, 4030, 4033, 4059, 4080, 4082, 4085, 4087, 4121, 4133, 4142, 4143, 4144, 4158, 4160, 4167, 4171, 4172, 4199, 4204, 4226, 4235, 4239, 4256, 4274, 4277, 4287, 4306, 4344, 4346, 4354, 4380, 4410, 4415, 4416, 4424, 4429, 4447, 4462, 4479, 4482, 4495, 4502, 4508, 4519, 4521, 4522, 4524, 4528, 4536, 4545, 4555, 4556, 4571, 4607, 4612, 4619, 4622, 4634, 4644, 4666, 4672, 4687, 4692, 4720, 4747, 4755, 4778, 4784, 4793, 4796, 4827, 4840, 4848, 4868, 4869, 4878, 4885, 4920, 4931, 4948, 4949, 4951, 4960, 4996]
# Evaluation dataset shape: (365, 16, 2)
# Result in Binarizer.__init__: None
# Scores in Binarizer.binarize: None and shape: None
# Scores in Binarizer.binarize: None and shape: None
# Scores in Binarizer.binarize: None and shape: None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       3 evaluations = []
#       4 for model in tqdm(models, desc='Evaluate'):
# ----> 5     e = evaluate(model)
#       6     evaluations.append(e)
#       7 # Write to database
#
# Cell In[8], line 61, in evaluate(model_name)
#      58         continue
#      59     _params.append([e, base, heuristic, strategy])
# ---> 61 return [_e for p in _params for _e in _evaluate(p)]
#
# Cell In[8], line 61, in <listcomp>(.0)
#      58         continue
#      59     _params.append([e, base, heuristic, strategy])
# ---> 61 return [_e for p in _params for _e in _evaluate(p)]
#
# Cell In[8], line 13, in _evaluate(params)
#      11     print(f"Models from session: {model}")
#      12 # Generate evaluation frames
# ---> 13 y_pred = e.binarizer.binarize(base=base, heuristic=heuristic, strategy=strategy, go_backwards=False)
#      14 y_true = e.binarizer.get_targets()
#      16 evaluations = []
#
# File d:\LTNcoder\april\anomalydetection\utils\binarizer.py:227, in Binarizer.binarize(self, scores, tau, base, heuristic, strategy, go_backwards, return_parameters, axis, heuristic_axis)
#     225         tau = self.get_legacy_tau(scores=scores, heuristic=heuristic, strategy=strategy, axis=heuristic_axis)
#     226     else:
# --> 227         tau = self.get_tau(scores=scores, heuristic=heuristic, strategy=strategy, axis=heuristic_axis)
#     229 # Apply the threshold function (Theta in the paper)
#     230 predictions = self.threshold_binarize(scores=scores, tau=tau, axis=axis)
#
# File d:\LTNcoder\april\anomalydetection\utils\binarizer.py:164, in Binarizer.get_tau(self, scores, heuristic, strategy, axis, taus)
#     161         return self.correct_shape([np.median(s[np.round(s, 1) > 0]) for s in scores], strategy)
#     163 if taus is None:
# --> 164     taus = [self.get_candidate_taus(s, axis=axis) for s in scores]
#     165 else:
#     166     taus = [taus] * len(scores)
#
# File d:\LTNcoder\april\anomalydetection\utils\binarizer.py:164, in <listcomp>(.0)
#     161         return self.correct_shape([np.median(s[np.round(s, 1) > 0]) for s in scores], strategy)
#     163 if taus is None:
# --> 164     taus = [self.get_candidate_taus(s, axis=axis) for s in scores]
#     165 else:
#     166     taus = [taus] * len(scores)
#
# File d:\LTNcoder\april\anomalydetection\utils\binarizer.py:97, in Binarizer.get_candidate_taus(self, a, axis)
#      95 def get_candidate_taus(self, a, axis=0):
#      96     a = max_collapse(a, axis=axis).compressed()
# ---> 97     a_min = a.min()
#      98     a_max = a.max()
#      99     if a_max > a_min:
#
# File c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity

# %%
session = Session(get_engine())
evaluations = session.query(Evaluation).all()
rows = []

for ev in tqdm(evaluations):
    # print(f"Evaluation: {ev}")
    m = ev.model
    # print(f"Model: {m}")
    el = ev.model.training_event_log
    # print(f"Event log: {el}")
    rows.append([m.file_name, m.creation_date, m.hyperparameters, m.training_duration, m.training_host, m.algorithm, 
                 el.name, el.base_name, el.percent_anomalies, el.number,
                 ev.axis, ev.base, ev.heuristic, ev.strategy, ev.label, ev.attribute_name, ev.perspective, ev.precision, ev.recall, ev.f1])
session.close()
columns = ['file_name', 'date', 'hyperparameters', 'training_duration', 'training_host', 'ad',
           'dataset_name', 'process_model', 'noise', 'dataset_id',
           'axis', 'base', 'heuristic', 'strategy', 'label', 'attribute_name', 'perspective', 'precision', 'recall', 'f1']
evaluation = pd.DataFrame(rows, columns=columns)

evaluation.to_pickle(eval_file)

# %%
synth_datasets = ['paper', 'p2p', 'small', 'medium', 'large', 'huge', 'gigantic', 'wide']
bpic_datasets = ['bpic12', 'bpic13', 'bpic15', 'bpic17']
anonymous_datasets = ['real']
datasets = synth_datasets + bpic_datasets + anonymous_datasets
dataset_types = ['Synthetic', 'Real-life']

orig_ads = [ad['ad'].__name__ for ad in ads if "DAE" in ad['ad'].__name__]
new_ads = [ad['ad'].__name__ for ad in ads if "DAE" not in ad['ad'].__name__]
ads = orig_ads + new_ads

heuristics = [r'$best$', r'$default$', r'$elbow_\downarrow$', r'$elbow_\uparrow$', 
              r'$lp_\leftarrow$', r'$lp_\leftrightarrow$', r'$lp_\rightarrow$']
print(ads)

# %%
evaluation = evaluation.query(f'ad in {ads} and label == "Anomaly"')

# %%
evaluation['perspective-label'] = evaluation['perspective'] + '-' + evaluation['label']
evaluation['attribute_name-label'] = evaluation['attribute_name'] + '-' + evaluation['label']
evaluation['dataset_type'] = 'Synthetic'
evaluation.loc[evaluation['process_model'].str.contains('bpic'), 'dataset_type'] = 'Real-life'
evaluation.loc[evaluation['process_model'].str.contains('real'), 'dataset_type'] = 'Real-life'

# %%
_filtered_evaluation = evaluation.query(f'ad in {ads} and (strategy == "{Strategy.ATTRIBUTE}"'
                                       f' or (strategy == "{Strategy.SINGLE}" and process_model == "p2p")'
                                       f' or (strategy == "{Strategy.SINGLE}" and ad == "Naive+"))')

# %%
filtered_evaluation = _filtered_evaluation.query(f'heuristic == "{Heuristic.DEFAULT}"'
                                                 f' or (heuristic == "{Heuristic.LP_MEAN}" and ad in {orig_ads})'
                                                 f' or (heuristic == "{Heuristic.LP_LEFT}" and ad in {new_ads})'
                                                )

# %%
df = filtered_evaluation.query('axis == 0')
df = prettify_dataframe(df)
df = df.groupby(['axis', 'process_model', 'dataset_name', 'ad', 'file_name', 'perspective'])[['precision', 'recall', 'f1']].mean().reset_index()
df = df.groupby(['axis', 'process_model', 'dataset_name', 'ad', 'file_name'])[['precision', 'recall', 'f1']].mean().reset_index()
df['f1'] = 2 * df['recall'] * df['precision'] / (df['recall'] + df['precision'])

df = pd.pivot_table(df, index=['axis', 'ad'], columns=['process_model', 'dataset_name'], values=['precision', 'recall', 'f1'])
df = df.fillna(0)
df = df.stack(1).stack(1).reset_index()
df.to_excel(str(out_dir / 'table.xlsx'), index=False)

# drop rows in column "axis" which have value "Attribute"
df = df.query('axis != "Attribute"')

# df = pd.pivot_table(df, index=['axis', 'ad'], columns=['process_model'], values=['precision', 'recall', 'f1'], aggfunc=np.mean)

df.to_excel(str(excel_file), index=False)
df.to_csv(str(csv_file), index=False)
print(df)

# %%
display(df)
