# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sqlalchemy.orm import Session

from april.database import get_engine
from april.fs import PLOT_DIR
from april.utils import microsoft_colors
from april.utils import prettify_dataframe
from april.enums import Base, Strategy, Heuristic

sns.set_style('white')
pd.set_option('display.max_rows', 50)
# %config InlineBackend.figure_format = 'retina'
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU found
# Memory growth set
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPU found
# Memory growth set
# Creating Evaluation table

# %%
out_dir = PLOT_DIR / 'isj-2019'
eval_file = out_dir / 'eval.pkl'

# %% [markdown]
# ### Helper objects

# %%
synth_datasets = ['paper', 'p2p', 'small', 'medium', 'large', 'huge', 'gigantic', 'wide']
bpic_datasets = ['bpic12', 'bpic13', 'bpic15', 'bpic17']
anonymous_datasets = ['real']
datasets = synth_datasets + bpic_datasets + anonymous_datasets
dataset_types = ['Synthetic', 'Real-life']

binet_ads = ["BINetv1", "BINetv2", "BINetv3"]
nn_ads = ["DAE", "DAELTN", "DAELTNFROZEN"] + binet_ads
h_ads = nn_ads + [ "Likelihood+", "t-STIDE+", "Naive+"]
d_ads = ["naive", "sampling", "Likelihood", "OC-SVM"]
ads = h_ads + d_ads
h_ads = ads = ["DAE", "DAELTN", "DAELTNFROZEN"]
# ads = ['dae' 'naive' 'random' 'sampling']

heuristics = [r'$best$', r'$default$', r'$elbow_\downarrow$', r'$elbow_\uparrow$', 
              r'$lp_\leftarrow$', r'$lp_\leftrightarrow$', r'$lp_\rightarrow$']

# %% [markdown]
# ## Retrieve evaluations from pickle file

# %%
evaluation = pd.read_pickle(eval_file)

# %%
print(evaluation.head())
print(type(evaluation))
# Out:
#                                     file_name                       date  \
# 0  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 1  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 2  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 3  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 4  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
#
#                      hyperparameters  training_duration training_host   ad  \
# 0  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 1  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 2  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 3  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 4  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
#
#   dataset_name process_model  noise  dataset_id  axis    base heuristic  \
# 0    p2p-0.3-1           p2p    0.3           1     0  scores      best
# 1    p2p-0.3-1           p2p    0.3           1     0  scores      best
# 2    p2p-0.3-1           p2p    0.3           1     0  scores      best
# 3    p2p-0.3-1           p2p    0.3           1     0  scores      best
# 4    p2p-0.3-1           p2p    0.3           1     1  scores      best
#
#   strategy    label attribute_name   perspective  precision    recall  \
# 0   single   Normal           name  Control Flow   0.986779  0.987824
# 1   single  Anomaly           name  Control Flow   0.962233  0.959083
# 2   single   Normal           user          Data   0.904800  1.000000
# 3   single  Anomaly           user          Data   0.000000  0.000000
# 4   single   Normal           name  Control Flow   0.990835  0.964643
#
#          f1
# 0  0.987302
# 1  0.960656
# 2  0.950021
# 3  0.000000
# 4  0.977564
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Add identifier for BPIC datasets and filter for ADs

# %%
evaluation = evaluation.query(f'ad in {ads} and label == "Anomaly"')

# %%
print(evaluation.head())
# Out:
#                                     file_name                       date  \
# 1  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 3  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 5  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 7  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 9  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
#
#                      hyperparameters  training_duration training_host   ad  \
# 1  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 3  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 5  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 7  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 9  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
#
#   dataset_name process_model  noise  dataset_id  axis    base heuristic  \
# 1    p2p-0.3-1           p2p    0.3           1     0  scores      best
# 3    p2p-0.3-1           p2p    0.3           1     0  scores      best
# 5    p2p-0.3-1           p2p    0.3           1     1  scores      best
# 7    p2p-0.3-1           p2p    0.3           1     1  scores      best
# 9    p2p-0.3-1           p2p    0.3           1     2  scores      best
#
#   strategy    label attribute_name   perspective  precision    recall  \
# 1   single  Anomaly           name  Control Flow   0.962233  0.959083
# 3   single  Anomaly           user          Data   0.000000  0.000000
# 5   single  Anomaly           name  Control Flow   0.523493  0.813196
# 7   single  Anomaly           user          Data   0.000000  0.000000
# 9   single  Anomaly           name  Control Flow   0.523493  0.813196
#
#          f1
# 1  0.960656
# 3  0.000000
# 5  0.636951
# 7  0.000000
# 9  0.636951

# %%
evaluation['perspective-label'] = evaluation['perspective'] + '-' + evaluation['label']
evaluation['attribute_name-label'] = evaluation['attribute_name'] + '-' + evaluation['label']
evaluation['dataset_type'] = 'Synthetic'
evaluation.loc[evaluation['process_model'].str.contains('bpic'), 'dataset_type'] = 'Real-life'
evaluation.loc[evaluation['process_model'].str.contains('real'), 'dataset_type'] = 'Real-life'

# %% [markdown]
# ### Filter for best strategy

# %% [markdown]
# In `5.1 Best Strategy.ipynb` we find that $\tau_0$ and $\tau_a$ seem to work best overall. Intuatively it makes sense to set a threshold $\tau$ per attribute, hence we select $\tau_a$ whereever applicable.

# %%
_filtered_evaluation = evaluation.query(f'ad in {h_ads} and (strategy == "{Strategy.ATTRIBUTE}"'
                                       f' or (strategy == "{Strategy.SINGLE}" and process_model == "bpic12")'
                                       f' or (strategy == "{Strategy.SINGLE}" and ad == "Naive+")) or ad in {d_ads}')

# %%
print(_filtered_evaluation.head())
# Out:
#                                      file_name                       date  \
# 13  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 15  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 17  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 19  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 21  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
#
#                       hyperparameters  training_duration training_host   ad  \
# 13  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 15  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 17  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 19  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 21  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
#
#    dataset_name process_model  noise  dataset_id  ...   strategy    label  \
# 13    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 15    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 17    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 19    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 21    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
#
#    attribute_name   perspective precision    recall        f1  \
# 13           name  Control Flow  0.962233  0.959083  0.960656
# 15           user          Data  0.306096  0.495798  0.378508
# 17           name  Control Flow  0.523493  0.813196  0.636951
# 19           user          Data  0.303640  0.378282  0.336876
# 21           name  Control Flow  0.523493  0.813196  0.636951
#
#        perspective-label  attribute_name-label  dataset_type
# 13  Control Flow-Anomaly          name-Anomaly     Synthetic
# 15          Data-Anomaly          user-Anomaly     Synthetic
# 17  Control Flow-Anomaly          name-Anomaly     Synthetic
# 19          Data-Anomaly          user-Anomaly     Synthetic
# 21  Control Flow-Anomaly          name-Anomaly     Synthetic
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Filter for best heuristic

# %% [markdown]
# In `5.2 Best Heuristic.ipynb` we find that $lp_\rightarrow$ works best overall, aparat from DAE. For DAE we use $elbow_\uparrow$. For all default methods we use $default$.

# %%
# filtered_evaluation = _filtered_evaluation.query(f'heuristic == "{Heuristic.DEFAULT}"'
#                                                  f' or (heuristic == "{Heuristic.LP_MEAN}" and ad != "DAE")'
#                                                  f' or (heuristic == "{Heuristic.ELBOW_UP}" and ad == "DAE")'
#                                                  f' or (heuristic == "{Heuristic.LP_MEAN}" and ad != "DAELTN")'
#                                                  f' or (heuristic == "{Heuristic.ELBOW_UP}" and ad == "DAELTN")'
#                                                  f' or (heuristic == "{Heuristic.LP_MEAN}" and ad != "DAELTNFROZEN")'
#                                                  f' or (heuristic == "{Heuristic.ELBOW_UP}" and ad == "DAELTNFROZEN")'
#                                                  )

# %%
filtered_evaluation = _filtered_evaluation.query(f'heuristic == "{Heuristic.DEFAULT}"'
                                                 f' or (heuristic == "{Heuristic.LP_MEAN}" and ad != "DAE")'
                                                 f' or (heuristic == "{Heuristic.LP_LEFT}" and ad == "DAE")'
                                                 f' or (heuristic == "{Heuristic.LP_MEAN}" and ad != "DAELTN")'
                                                 f' or (heuristic == "{Heuristic.LP_LEFT}" and ad == "DAELTN")'
                                                 f' or (heuristic == "{Heuristic.LP_MEAN}" and ad != "DAELTNFROZEN")'
                                                 f' or (heuristic == "{Heuristic.LP_LEFT}" and ad == "DAELTNFROZEN")'
                                                )

# %%
print(filtered_evaluation.head())
# Out:
#                                       file_name                       date  \
# 157  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 159  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 161  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 163  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 165  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
#
#                        hyperparameters  training_duration training_host   ad  \
# 157  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 159  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 161  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 163  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 165  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
#
#     dataset_name process_model  noise  dataset_id  ...   strategy    label  \
# 157    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 159    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 161    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 163    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
# 165    p2p-0.3-1           p2p    0.3           1  ...  attribute  Anomaly
#
#     attribute_name   perspective precision    recall        f1  \
# 157           name  Control Flow  0.958855  0.877250  0.916239
# 159           user          Data  0.241107  0.512605  0.327957
# 161           name  Control Flow  0.586000  0.604124  0.594924
# 163           user          Data  0.250546  0.410501  0.311171
# 165           name  Control Flow  0.586000  0.604124  0.594924
#
#         perspective-label  attribute_name-label  dataset_type
# 157  Control Flow-Anomaly          name-Anomaly     Synthetic
# 159          Data-Anomaly          user-Anomaly     Synthetic
# 161  Control Flow-Anomaly          name-Anomaly     Synthetic
# 163          Data-Anomaly          user-Anomaly     Synthetic
# 165  Control Flow-Anomaly          name-Anomaly     Synthetic
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Overall Evaluation

# %%
df = filtered_evaluation.query('axis in [0, 2]')
df = prettify_dataframe(df)
df = df.groupby(['axis', 'dataset_type', 'ad', 'file_name', 'perspective'])[['precision', 'recall', 'f1']].mean().reset_index()
df = df.groupby(['axis', 'dataset_type', 'ad', 'file_name'])[['precision', 'recall', 'f1']].mean().reset_index()
df['f1'] = 2 * df['recall'] * df['precision'] / (df['recall'] + df['precision'])

pdf = df.melt(id_vars=['axis', 'ad', 'dataset_type'], value_vars=['precision', 'recall', 'f1'], var_name='metric')
g = sns.FacetGrid(data=pdf, row='metric', col='dataset_type', sharex=False, sharey=True, despine=False, aspect=2, col_order=dataset_types)
g = g.map_dataframe(sns.barplot, x='axis', y='value', hue='ad', palette=microsoft_colors, hue_order=ads, order=['Case', 'Attribute'])
g = g.add_legend()
# Out:
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ### Evaluation per perspective

# %%
df = filtered_evaluation.query('axis == 2')
df = prettify_dataframe(df)
df = df.melt(id_vars=['ad', 'dataset_type', 'perspective'], value_vars=['precision', 'recall', 'f1'], var_name='metric')
g = sns.FacetGrid(data=df, row='metric', col='dataset_type', sharex=False, sharey=True, despine=False, aspect=2, col_order=dataset_types)
g = g.map_dataframe(sns.barplot, x='perspective', y='value', hue='ad', palette=microsoft_colors, hue_order=ads)
g = g.add_legend()
# Out:
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ### Evaluation per attribute

# %%
df = filtered_evaluation.query('axis == 2')
df = prettify_dataframe(df)
df = df.melt(id_vars=['ad', 'dataset_type', 'attribute_name'], value_vars=['precision', 'recall', 'f1'], var_name='metric')
g = sns.FacetGrid(data=df, row='metric', col='dataset_type', sharex=False, sharey=True, despine=False, aspect=4, col_order=dataset_types)
g = g.map_dataframe(sns.barplot, x='attribute_name', y='value', hue='ad', palette=microsoft_colors, hue_order=ads)
g = g.add_legend()
# Out:
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ## Evaluation per Process Model on Synthetic Data

# %%
df = filtered_evaluation.query('axis == 2 and dataset_type == "Synthetic"')
df = prettify_dataframe(df)
df = df.groupby(['ad', 'file_name', 'process_model', 'perspective'])[['precision', 'recall', 'f1']].mean().reset_index()
df = df.groupby(['ad', 'file_name', 'process_model'])[['precision', 'recall', 'f1']].mean().reset_index()
df['f1'] = 2 * df['recall'] * df['precision'] / (df['recall'] + df['precision'])
df['f1'] = df['f1'].fillna(0)
df = df.melt(id_vars=['ad', 'process_model'], value_vars=['precision', 'recall', 'f1'], var_name='metric')

dataset_order = ['Paper', 'P2P', 'Small', 'Medium', 'Large', 'Huge', 'Gigantic']
g = sns.FacetGrid(data=df, row='metric', sharex=False, sharey=True, despine=False, aspect=5)
g = g.map_dataframe(sns.barplot, x='process_model', y='value', hue='ad', palette=microsoft_colors, hue_order=ads, order=dataset_order)
g = g.add_legend()
# Out:
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)
# c:\Users\devas\anaconda3\envs\ltn\lib\site-packages\seaborn\axisgrid.py:854: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ## Evaluation on Real data

# %%
# df = filtered_evaluation.query(f'axis == 2 and dataset_type == "Real"')
# df = prettify_dataframe(df)
# df = df.groupby(['dataset_name', 'ad', 'file_name', 'perspective'])[['precision', 'recall', 'f1']].mean().reset_index()
# df = df.groupby(['dataset_name', 'ad', 'file_name'])[['precision', 'recall', 'f1']].mean().reset_index()
# df['f1'] = 2 * df['recall'] * df['precision'] / (df['recall'] + df['precision'])
# df['f1'] = df['f1'].fillna(0)
# df = df.melt(id_vars=['ad', 'dataset_name'], value_vars=['precision', 'recall', 'f1'], var_name='metric')
# g = sns.FacetGrid(data=df, row='metric', sharex=False, sharey=True, despine=False, aspect=5)
# g = g.map_dataframe(sns.barplot, x='dataset_name', y='value', hue='ad', palette=microsoft_colors, hue_order=ads)
# g = g.add_legend()

# %% [markdown]
# # Evaluation table

# %%
df = filtered_evaluation
df = prettify_dataframe(df)
df = df.groupby(['axis', 'dataset_name', 'ad', 'file_name', 'perspective'])[['precision', 'recall', 'f1']].mean().reset_index()

def plot_heatmap(**kwargs):
    df = kwargs.pop('data')
    hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)
    sns.heatmap(hm, **kwargs)
    
g = sns.FacetGrid(data=df, col='perspective', row='axis', sharey=True, sharex=True, despine=False, height=4, aspect=2, margin_titles=False)
g = g.map_dataframe(plot_heatmap, cmap='Blues', vmin=0.0, vmax=1.0, square=False, annot=False, cbar=False, fmt='.2f')
# Out:
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\2719298392.py:7: FutureWarning: The provided callable <function mean at 0x000001562F3ACB80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\2719298392.py:7: FutureWarning: The provided callable <function mean at 0x000001562F3ACB80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\2719298392.py:7: FutureWarning: The provided callable <function mean at 0x000001562F3ACB80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\2719298392.py:7: FutureWarning: The provided callable <function mean at 0x000001562F3ACB80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\2719298392.py:7: FutureWarning: The provided callable <function mean at 0x000001562F3ACB80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\2719298392.py:7: FutureWarning: The provided callable <function mean at 0x000001562F3ACB80> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   hm = pd.pivot_table(df, values='f1', index=['ad'], columns=['dataset_name'], aggfunc=np.mean)

# %% [markdown]
# ## A3 Training duration

# %%
print(evaluation.head())
durations = evaluation[['ad', 'dataset_name', 'process_model', 'dataset_type', 'dataset_id', 'training_duration']].drop_duplicates()
print(durations)
durations = durations.query('dataset_type != "bpic"')
fig = plt.subplots(figsize=(16, 4))
g = sns.barplot(data=durations, x='process_model', y='training_duration', hue='ad', palette=microsoft_colors, errwidth=0, hue_order=ads, order=synth_datasets)
g = plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
# Out:
#                                     file_name                       date  \
# 1  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 3  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 5  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 7  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
# 9  p2p-0.3-1_dae_20250417-094403.669280.keras 2025-04-17 09:44:16.503958
#
#                      hyperparameters  training_duration training_host   ad  \
# 1  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 3  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 5  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 7  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
# 9  {'epochs': 20, 'batch_size': 100}          12.834678       Dev-RTX  DAE
#
#   dataset_name process_model  noise  dataset_id  ...  strategy    label  \
# 1    p2p-0.3-1           p2p    0.3           1  ...    single  Anomaly
# 3    p2p-0.3-1           p2p    0.3           1  ...    single  Anomaly
# 5    p2p-0.3-1           p2p    0.3           1  ...    single  Anomaly
# 7    p2p-0.3-1           p2p    0.3           1  ...    single  Anomaly
# 9    p2p-0.3-1           p2p    0.3           1  ...    single  Anomaly
#
#   attribute_name   perspective precision    recall        f1  \
# 1           name  Control Flow  0.962233  0.959083  0.960656
# 3           user          Data  0.000000  0.000000  0.000000
# 5           name  Control Flow  0.523493  0.813196  0.636951
# 7           user          Data  0.000000  0.000000  0.000000
# 9           name  Control Flow  0.523493  0.813196  0.636951
#
#       perspective-label  attribute_name-label  dataset_type
# 1  Control Flow-Anomaly          name-Anomaly     Synthetic
# 3          Data-Anomaly          user-Anomaly     Synthetic
# 5  Control Flow-Anomaly          name-Anomaly     Synthetic
# 7          Data-Anomaly          user-Anomaly     Synthetic
# 9  Control Flow-Anomaly          name-Anomaly     Synthetic
#
# [5 rows x 23 columns]
#                ad dataset_name process_model dataset_type  dataset_id  \
# 1             DAE    p2p-0.3-1           p2p    Synthetic           1
# 289        DAELTN    p2p-0.3-1           p2p    Synthetic           1
# 577  DAELTNFROZEN    p2p-0.3-1           p2p    Synthetic           1
#
#      training_duration
# 1            12.834678
# 289         114.281783
# 577         118.344116
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\1939336245.py:6: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   g = sns.barplot(data=durations, x='process_model', y='training_duration', hue='ad', palette=microsoft_colors, errwidth=0, hue_order=ads, order=synth_datasets)
# C:\Users\devas\AppData\Local\Temp\ipykernel_28804\1939336245.py:6: FutureWarning:
#
# The `errwidth` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'linewidth': 0}` instead.
#
#   g = sns.barplot(data=durations, x='process_model', y='training_duration', hue='ad', palette=microsoft_colors, errwidth=0, hue_order=ads, order=synth_datasets)
